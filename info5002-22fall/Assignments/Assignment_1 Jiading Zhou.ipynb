# %% [markdown]
# # Assignment 1
# ### Introduction to python

# %% [markdown]
# #### Q1 - What are the Key features of Python?

# %% [markdown]
# Python is a simple programming language that is easy to learn, and can also provide fast edit cycles and smooth development. It has so many key features for developer and non-developer to code and excuate.
# - Python is easy to code and easy to read. The syntax is close to natural language that people say everyday.
# - open and free source for users to search and find easily, including many standard libraries. (ex: databases, image manipulation, and testing etc.)
# - Python support the object-orientated programing, which is important and efficient to work.
# - It is a high-level language that no need to concern the system architecture.
# - Python is a an integrated and portable language that very convenient to use in different operation system, Windows, ManOS, Linux, and easily to integrate with C and C++.
# - Python has the dynamic features, which means no needy to define the data type and memory will dynamically allocate at run time.

# %% [markdown]
# #### Q2 - What are local variables and global variables in Python?

# %% [markdown]
# - Local variables also call the internal variables and global variables can state as the external variables. A function's internal variables have a local scope, but external variables have a global scope. This indicates that global variables may be accessible by all functions throughout the program body, but local variables can only be accessed within the function in which they are defined.

# %% [markdown]
# #### Q3 - Remove the error from the below cell:

# %%
print('Hi, I am Python with version')
print('Hi, I am Python with version+3')

# rm "+3", or put "+3" inside the '' also works

# %% [markdown]
# #### Q4 - Define the below operators and give one example each.
# Arithmetic Operators <br/>
# Comparison (Relational) Operators <br/>
# Assignment Operators <br/>
# Logical Operators <br/>

# %% [markdown]
# - Arithmetic Operators are used with numeric values to perform common mathematical operations, such as  +   -   *   /   //   %   **
# - Comparison (Relational) Operators are relational operators are used for comparing the values. It either returns True or False according to the condition, such as < > == != <= >=
# - Assignment Operators are used to perform operations on values and variables. These are used to assign values to variables, which can carry out arithmetic, logical, bitwise computations, such as += -= /= %/
# - Logical Operators are used to perform operations on values and variables. It can combine conditional statements, such as and, or, not

# %% [markdown]
# #### Q5 - Write the data type of the below variables, Also create the int data type variable into string.

# %%
a = 100.00 
b = 2
c = 'Going Great'

# a is float
# b is int (integer)
# c is string
b = '2'  # create the int data type variable into string, 2 is int and '2' is string

# %% [markdown]
# #### Q6 - Write Script Mode Programming, create a file name python.py and print "Hello Intro to Python" and run the file and get output. Paste the screenshot of output on below cell.

# %% [markdown]
# ![Screen%20Shot%202022-09-28%20at%202.53.31%20PM.png](attachment:Screen%20Shot%202022-09-28%20at%202.53.31%20PM.png)

# %% [markdown]
# #### Q7 - What is Python Identifiers? Also, write naming conventions for Python identifiers.

# %% [markdown]
# - Python identifiers are basically the name of variables.
# - Python identifier, a name used to identify a variable, function, class, module or other object, has some naming rules which start with a letter A to Z or a to z or an underscore (_) followed by zero or more letters, underscores and digits (0 to 9)
# - Examples: list1, Dict2, getLargestNumber, find_error, x1_x2

# %% [markdown]
# #### Q8 - What is Reserved words in python? Name and describe any 5 of them.

# %% [markdown]
# - Reserved words (also called keywords) are defined with predefined meaning and syntax in the language. These keywords have to be used to develop programming instructions. Reserved words can't be used as identifiers for other programming elements like name of variable, function etc.
#     - for "for" is reserved word in for loop, which is a loop that programmer know where the end is. It will excuate every item and goes to the last of it.
#     - while  "while" is reserved word in while loop, which an inifinte loop that programmer would not know the end of it. It can be set up the condintional statements. When the condition meets, the while loop will end itself and output the result.
#     - if elif else  "if elif else" is the reserved words used to compare between two statements. If the condition meet it will go to the excuate it. However, it is doesn't meet, it will skip and excuate the following.
#     - def  "def" is the reserved word for define the function, it is placed before a function name that is provided by the user to create a user-defined function. The user-defined function can be called at the following program.
#     - class  "class" is a reserved word for create the class or object. A user-defined class serves as a template or prototype from which objects can be built. Classes offer a way to group together functionality and data. A new class produces a new type of object, enabling the creation of new instances of that type. Each instance of a class may have characteristics connected to it to preserve its state. Class instances may also contain methods for changing their state that are defined by their class.

# %% [markdown]
# #### Q9 - Write a multi line code for the string given below (Divide below single line it into 5 line).
#
# queryText= "SELECT * FROM TABLE1 AS T1
# JOIN TABLE2 AS T2 ON T1.SOMETHING = T2.SOMETHING
# JOIN TABLE3 AS T3 ON T3.SOMETHING = T2.SOMETHING
# WHERE SOMETHING BETWEEN <WHATEVER> AND <WHATEVER ELSE>
# ORDER BY WHATEVERS DESC"

# %%
queryText = '''SELECT * FROM TABLE1 AS T1
    JOIN TABLE2 AS T2 ON T1.SOMETHING = T2.SOMETHING
    JOIN TABLE3 AS T3 ON T3.SOMETHING = T2.SOMETHING
WHERE SOMETHING BETWEEN <WHATEVER> AND <WHATEVER ELSE>
ORDER BY WHATEVERS DESC'''
print(queryText)

# %% [markdown]
# #### Q10 - Describe single ('), double (") and triple (''' or """) quotes in python, Give examples for each. Also how do we comment in python? Give example for the same.

# %% [markdown]
# - single (') quotes can make it into a string.
# - double (") quotes can also make it into a string
# - triple (''' or """) quotes can also make it into a string, but it can make all string in multiple lines.
# - (#) can make comment in python. Everything after # will not be excuated, it becomes prue text comments for other programmers to read.

# %%
ex1 = 'abc' 
print(ex1)  # abc
print(type(ex1)) # <class 'str'>

ex2 = "xyz" 
print(ex2)  # xyz
print(type(ex1)) # <class 'str'>

ex3 = '''HIJK
LMN'''
print(ex3)  # HIJK
            # LMN
print(type(ex3))  # <class 'str'>

#############################
# this is a comment. 
# this is also a comment. 
# we are comments. 
#############################
